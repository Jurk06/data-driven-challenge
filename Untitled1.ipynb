# %%
# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -P "/content/drive/My Drive/app"
# Out:
# --2018-10-14 16:23:29--  https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170 (1.1K) [text/plain]
# Saving to: ‘/content/drive/My Drive/app/Titanic.csv’
#
# Titanic.csv         100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2018-10-14 16:23:29 (108 MB/s) - ‘/content/drive/My Drive/app/Titanic.csv’ saved [1170/1170]

# %%
import pandas as pd
df=pd.read_csv("/content/drive/My Drive/app/Titanic.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Class     Sex    Age Survived  Freq
# 0           1   1st    Male  Child       No     0
# 1           2   2nd    Male  Child       No     0
# 2           3   3rd    Male  Child       No    35
# 3           4  Crew    Male  Child       No     0
# 4           5   1st  Female  Child       No     0

# %%
df.shape
# Out:
# (32, 6)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
from sklearn.model_selection import train_test_split

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'Class', u'Sex', u'Age', u'Survived', u'Freq'], dtype='object')

# %%
df.Age.value_counts()
# Out:
# Child    16
# Adult    16
# Name: Age, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# Male      16
# Female    16
# Name: Sex, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# No     16
# Yes    16
# Name: Survived, dtype: int64

# %%
df.Freq.value_counts()
# Out:
# 0      8
# 13     3
# 14     2
# 140    1
# 1      1
# 35     1
# 4      1
# 5      1
# 57     1
# 11     1
# 387    1
# 670    1
# 80     1
# 17     1
# 192    1
# 20     1
# 76     1
# 118    1
# 89     1
# 154    1
# 3      1
# 75     1
# Name: Freq, dtype: int64
